# %%
print("00_averages.py")

def average(a: float, b: float):
    sum = a + b
    return sum / 2

def main():
    avg_1 = average(0, 10)
    avg_2 = average(8, 10)

    final = average(avg_1, avg_2)

    print("avg_1", avg_1)
    print("avg_2", avg_2)
    print("final", final)

if __name__ == '__main__':
    main()
# Out:
# 00_averages.py
# avg_1 5.0
# avg_2 9.0
# final 7.0

# %%
print("01_chaotic_counting.py")

import random

DONE_LIKELIHOOD = 0.3

def chaotic_counting():
    for i in range(10):
        curr_num = i + 1
        if done():
            return
        print(curr_num)

def done():
    """ Returns True with a probability of DONE_LIKELIHOOD """
    if random.random() < DONE_LIKELIHOOD:
        return True
    return False

def main():
    print("I'm going to count until 10 or until I feel like stopping, whichever comes first.")
    chaotic_counting()
    print("I'm done.")

if __name__ == "__main__":
    main()
# Out:
# 01_chaotic_counting.py
# I'm going to count until 10 or until I feel like stopping, whichever comes first.
# I'm done.

# %%
print("02_count_even.py")


def count_even(lst):
    count = 0
    for num in lst:
        if num % 2 == 0:
            count += 1

    print(count)

def get_list_of_ints():
    lst = []
    user_input = input("Enter an integer or press enter to stop: ")

    while user_input != "":
        lst.append(int(user_input))
        user_input = input("Enter an integer or press enter to stop: ")

    return lst

def main():
    lst = get_list_of_ints()
    count_even(lst)

if __name__ == '__main__':
    main()
# Out:
# 02_count_even.py
# Enter an integer or press enter to stop: 0
# Enter an integer or press enter to stop: 1
# Enter an integer or press enter to stop: 2
# Enter an integer or press enter to stop: -2
# Enter an integer or press enter to stop:
# 3

# %%
print("03_double.py")

def double(num: int):
    return num * 2

def main():
    num = int(input("Enter a number: "))
    num_times_2 = double(num)
    print("Double that is", num_times_2)

if __name__ == '__main__':
    main()
# Out:
# 03_double.py
# Enter a number: 2
# Double that is 4

# %%
print("04_get_name.py")


def get_name():
    return "Muntaha"

def main():
    name = get_name()
    print("Howdy", name, "! 🤠")

if __name__ == '__main__':
    main()
# Out:
# 04_get_name.py
# Howdy Muntaha ! 🤠

# %%
print("05_is_odd.py")

def main():
    for i in range(10, 20):
        if is_odd(i):
            print(i, "odd")
        else:
            print(i, "even")

def is_odd(value: int):
    remainder = value % 2
    return remainder == 1

if __name__ == '__main__':
    main()
# Out:
# 05_is_odd.py
# 10 even
# 11 odd
# 12 even
# 13 odd
# 14 even
# 15 odd
# 16 even
# 17 odd
# 18 even
# 19 odd

# %%
print("06_print_divisor.py")

def print_divisors(num: int):
    print("Here are the divisors of", num)
    for i in range(num):
        curr_divisor = i + 1
        if num % curr_divisor == 0:
            print(curr_divisor)

def main():
    num = int(input("Enter a number: "))
    print_divisors(num)

if __name__ == '__main__':
    main()
# Out:
# 06_print_divisor.py
# Enter a number: 10
# Here are the divisors of 10
# 1
# 2
# 5
# 10

# %%
print("07_print_multiple.py")

def print_multiple(message: str, repeats: int):
    for i in range(repeats):
        print(message)

def main():
    message = input("Please type a message: ")
    repeats = int(input("Enter a number of times to repeat your message: "))
    print_multiple(message, repeats)

if __name__ == '__main__':
    main()
# Out:
# 07_print_multiple.py
# Please type a message: hello
# Enter a number of times to repeat your message: 4
# hello
# hello
# hello
# hello

# %%
print("08_sentence_generator.py")

def make_sentence(word, part_of_speech):
    if part_of_speech == 0:
        print("I am excited to add this " + word + " to my vast collection of them!")
    elif part_of_speech == 1:
        print("It's so nice outside today it makes me want to " + word + "!")
    elif part_of_speech == 2:
        print("Looking out my window, the sky is big and " + word + "!")
    else:
        print("Part of speech must be 0, 1, or 2! Can't make a sentence.")

def main():
    word: str = input("Please type a noun, verb, or adjective: ")
    print("Is this a noun, verb, or adjective?")
    part_of_speech = int(input("Type 0 for noun, 1 for verb, 2 for adjective: "))
    make_sentence(word, part_of_speech)

if __name__ == '__main__':
    main()
# Out:
# 08_sentence_generator.py

# %%
print("09_print_ones_digit.py")

def print_ones_digit(num):
    print("The ones digit is", num % 10)

def main():
    num = int(input("Enter a number: "))
    print_ones_digit(num)

if __name__ == '__main__':
    main()
# Out:
# 09_print_ones_digit.py
# Enter a number: 2
# The ones digit is 2
